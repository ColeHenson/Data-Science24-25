# %% [markdown]
# # Unit 1 Exercises: Data Structure Concepts
#
# The following questions will ask you to describe the various objects we learned about in the first Unit.
#
# I'm not giving you coding exercises, because we will learn all the coding technqiues we need as we move through the course.
#
# What I do need from you right now, is a conceptual understanding how how data is stored in our computer, when we use python.

# %% [markdown]
# **Task1**:
#
# Describe the similarities and differences between an int and a float in python.

# %% [markdown]
# Both ints and floats hold numeric values, however, integers are limited to integers and floats represent real numbers.

# %% [markdown]
# **Task2**:
#
# Describe the similarities and differences between: strings, lists, and dicts.

# %% [markdown]
# Strings contain lists of character while lists and dicts contain lists of any data type. Data in a dict is stored as a key value pair called an item.
#
# [*write your answer here*]

# %% [markdown]
# **Task3**:
#
# What is a numpy array? Why would we ever use one over a list or dict?

# %% [markdown]
# A numpy arrays are immutable lists that can only contain one data type.

# %% [markdown]
# **Task4**:
#
# What is a pandas dataframe? Why would we ever want to use one over a numpy array?

# %% [markdown]
# A pandas data frame is a data used to store and frame data in python. The benefit to using the pandas data frame over a numpy array is that pandas works with data organized into rows and collumns.

# %% [markdown]
# **Task5**:
#
# What are for loops, and why would we ever use them?

# %% [markdown]
# For loops allow for sections of code to be repeated until a condition is met and they are useful when iterating over a set of data.
